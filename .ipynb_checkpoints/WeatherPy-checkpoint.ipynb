# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import requests

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries= []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        

# Print the city count to confirm sufficient count
len(cities)
list_of_cities = pd.DataFrame({"city" : cities})
list_of_cities
# Out:
#                          city
# 0              krasnozerskoye
# 1                       kutum
# 2                     rikitea
# 3                     ushuaia
# 4               palabuhanratu
# 5                 port alfred
# 6                      albany
# 7                    cidreira
# 8                     mataura
# 9                       tabou
# 10                     kupang
# 11                   victoria
# 12            arraial do cabo
# 13                    uruzgan
# 14               punta arenas
# 15               longyearbyen
# 16                    amderma
# 17                  kabanjahe
# 18       cagayan de tawi-tawi
# 19                    koboldo
# 20                     atuona
# 21                barentsburg
# 22                  upernavik
# 23                      semey
# 24                       hilo
# 25                      altea
# 26                  kavaratti
# 27           illoqqortoormiut
# 28                      vaini
# 29                   upington
# ..                        ...
# 582               bahia honda
# 583                 otradnoye
# 584                brokopondo
# 585               canyon lake
# 586                     terni
# 587                willowmore
# 588                     kimbe
# 589                     chase
# 590                   mokrous
# 591                     baiao
# 592                baker city
# 593          fort myers beach
# 594                   camocim
# 595                   buldana
# 596                   klyuchi
# 597                 ibotirama
# 598  sao domingos do maranhao
# 599              torbat-e jam
# 600                    hasaki
# 601                      amga
# 602                 lydenburg
# 603         sosnovo-ozerskoye
# 604                   iquitos
# 605                   aklavik
# 606                farmington
# 607                      nome
# 608                 manokwari
# 609                 shelburne
# 610                    mwanza
# 611            terekli-mekteb
#
# [612 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setting up values for OpenWeatherMap API calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

app_id = api_key

params = { "appid" :app_id,"units":"Imperial" }
row_count = 0
for index,row in list_of_cities.iterrows():
    params["q"] =f'{row["city"]}'
    print(f"Processing Record {row_count} | {params['q']}")
    city_weather_resp = requests.get(base_url,params)
    print(city_weather_resp.url)
    city_weather_resp  = city_weather_resp.json()
    try:
        list_of_cities.set_value(index,"Cloudiness",city_weather_resp.get("clouds",{}).get("all"))
        list_of_cities.set_value(index,"Country",city_weather_resp.get("sys",{}).get("country"))
        list_of_cities.set_value(index,"Humidity",city_weather_resp.get("main",{}).get("humidity"))
        list_of_cities.set_value(index,"Latitude",city_weather_resp.get("coord",{}).get("lat"))
        list_of_cities.set_value(index,"Longitude",city_weather_resp.get("coord",{}).get("lon"))
        list_of_cities.set_value(index,"Max Temperature",city_weather_resp.get("main",{}).get("temp_max"))
        list_of_cities.set_value(index,"Wind Speed",city_weather_resp.get("wind",{}).get("speed"))
        row_count = row_count + 1
    except(ValueError, KeyError , IndexError):
        print("missing result...... skiping to next city on list")
# Out:
# Processing Record 0 | krasnozerskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=krasnozerskoye
# Processing Record 1 | kutum
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kutum
# Processing Record 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rikitea
# Processing Record 3 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ushuaia
# Processing Record 4 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=palabuhanratu
# Processing Record 5 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+alfred
# Processing Record 6 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=albany
# Processing Record 7 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cidreira
# Processing Record 8 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mataura
# Processing Record 9 | tabou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tabou
# Processing Record 10 | kupang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kupang
# Processing Record 11 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=victoria
# Processing Record 12 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=arraial+do+cabo
# Processing Record 13 | uruzgan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=uruzgan
# Processing Record 14 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=punta+arenas
# Processing Record 15 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=longyearbyen
# Processing Record 16 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=amderma
# Processing Record 17 | kabanjahe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kabanjahe
# Processing Record 18 | cagayan de tawi-tawi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cagayan+de+tawi-tawi
# Processing Record 19 | koboldo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=koboldo
# Processing Record 20 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=atuona
# Processing Record 21 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=barentsburg
# Processing Record 22 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=upernavik
# Processing Record 23 | semey
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=semey
# Processing Record 24 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hilo
# Processing Record 25 | altea
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=altea
# Processing Record 26 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kavaratti
# Processing Record 27 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=illoqqortoormiut
# Processing Record 28 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vaini
# Processing Record 29 | upington
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=upington
# Processing Record 30 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mys+shmidta
# Processing Record 31 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cabo+san+lucas
# Processing Record 32 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=esperance
# Processing Record 33 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=qasigiannguit
# Processing Record 34 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cape+town
# Processing Record 35 | jingcheng
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jingcheng
# Processing Record 36 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vestmannaeyjar
# Processing Record 37 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vilyuysk
# Processing Record 38 | batamshinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=batamshinskiy
# Processing Record 39 | indri
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=indri
# Processing Record 40 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bluff
# Processing Record 41 | krasnyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=krasnyy+yar
# Processing Record 42 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint-philippe
# Processing Record 43 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=padang
# Processing Record 44 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=belyy+yar
# Processing Record 45 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ketchikan
# Processing Record 46 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=qaanaaq
# Processing Record 47 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=guerrero+negro
# Processing Record 48 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saskylakh
# Processing Record 49 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=thompson
# Processing Record 50 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=busselton
# Processing Record 51 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mahebourg
# Processing Record 52 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=necochea
# Processing Record 53 | marica
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=marica
# Processing Record 54 | eyl
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=eyl
# Processing Record 55 | manicore
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=manicore
# Processing Record 56 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tuktoyaktuk
# Processing Record 57 | spas-demensk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=spas-demensk
# Processing Record 58 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hobart
# Processing Record 59 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jamestown
# Processing Record 60 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kodiak
# Processing Record 61 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=geraldton
# Processing Record 62 | bulungu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bulungu
# Processing Record 63 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tuatapere
# Processing Record 64 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hithadhoo
# Processing Record 65 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=luderitz
# Processing Record 66 | kijang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kijang
# Processing Record 67 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=krasnoselkup
# Processing Record 68 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=butaritari
# Processing Record 69 | awbari
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=awbari
# Processing Record 70 | abalak
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=abalak
# Processing Record 71 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mahajanga
# Processing Record 72 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nanakuli
# Processing Record 73 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=faanui
# Processing Record 74 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kapaa
# Processing Record 75 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=clyde+river
# Processing Record 76 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=atar
# Processing Record 77 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=richards+bay
# Processing Record 78 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=attawapiskat
# Processing Record 79 | maghama
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=maghama
# Processing Record 80 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=castro
# Processing Record 81 | zhangye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=zhangye
# Processing Record 82 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kruisfontein
# Processing Record 83 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=provideniya
# Processing Record 84 | zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=zapolyarnyy
# Processing Record 85 | moron
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=moron
# Processing Record 86 | ternate
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ternate
# Processing Record 87 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fairbanks
# Processing Record 88 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mar+del+plata
# Processing Record 89 | bose
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bose
# Processing Record 90 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bredasdorp
# Processing Record 91 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cherskiy
# Processing Record 92 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=east+london
# Processing Record 93 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nanortalik
# Processing Record 94 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=barrow
# Processing Record 95 | dir
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dir
# Processing Record 96 | constantine
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=constantine
# Processing Record 97 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=taolanaro
# Processing Record 98 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=svetlogorsk
# Processing Record 99 | yetholm
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yetholm
# Processing Record 100 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yellowknife
# Processing Record 101 | srandakan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=srandakan
# Processing Record 102 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=umzimvubu
# Processing Record 103 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=airai
# Processing Record 104 | halalo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=halalo
# Processing Record 105 | amot
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=amot
# Processing Record 106 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=aswan
# Processing Record 107 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+anthony
# Processing Record 108 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=udachnyy
# Processing Record 109 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=auki
# Processing Record 110 | campbell river
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=campbell+river
# Processing Record 111 | la palma
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=la+palma
# Processing Record 112 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=avarua
# Processing Record 113 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ribeira+grande
# Processing Record 114 | morondava
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=morondava
# Processing Record 115 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port-gentil
# Processing Record 116 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=champerico
# Processing Record 117 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tumannyy
# Processing Record 118 | la raya de santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=la+raya+de+santa+maria
# Processing Record 119 | brahmapuri
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=brahmapuri
# Processing Record 120 | waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=waingapu
# Processing Record 121 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ust-nera
# Processing Record 122 | chisinau
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chisinau
# Processing Record 123 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=grand+river+south+east
# Processing Record 124 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+george
# Processing Record 125 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=codrington
# Processing Record 126 | binghamton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=binghamton
# Processing Record 127 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=strezhevoy
# Processing Record 128 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=srednekolymsk
# Processing Record 129 | burica
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=burica
# Processing Record 130 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sur
# Processing Record 131 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lebu
# Processing Record 132 | alpena
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=alpena
# Processing Record 133 | ashitkovo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ashitkovo
# Processing Record 134 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bambous+virieux
# Processing Record 135 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=severo-kurilsk
# Processing Record 136 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=egvekinot
# Processing Record 137 | khonuu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=khonuu
# Processing Record 138 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vila+velha
# Processing Record 139 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bur+gabo
# Processing Record 140 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=olafsvik
# Processing Record 141 | coos bay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=coos+bay
# Processing Record 142 | esso
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=esso
# Processing Record 143 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sitka
# Processing Record 144 | samba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=samba
# Processing Record 145 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kahului
# Processing Record 146 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sinnamary
# Processing Record 147 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=georgetown
# Processing Record 148 | fallon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fallon
# Processing Record 149 | college
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=college
# Processing Record 150 | dobric
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dobric
# Processing Record 151 | fengcheng
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fengcheng
# Processing Record 152 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bambanglipuro
# Processing Record 153 | mbigou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mbigou
# Processing Record 154 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=itarema
# Processing Record 155 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chokurdakh
# Processing Record 156 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tsihombe
# Processing Record 157 | anar darreh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=anar+darreh
# Processing Record 158 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kavieng
# Processing Record 159 | vredendal
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vredendal
# Processing Record 160 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fort+nelson
# Processing Record 161 | blankenberge
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=blankenberge
# Processing Record 162 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mayo
# Processing Record 163 | la paz
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=la+paz
# Processing Record 164 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bathsheba
# Processing Record 165 | ankang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ankang
# Processing Record 166 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dikson
# Processing Record 167 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hermanus
# Processing Record 168 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=puerto+ayora
# Processing Record 169 | amahai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=amahai
# Processing Record 170 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=laguna
# Processing Record 171 | puro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=puro
# Processing Record 172 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=souillac
# Processing Record 173 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nouadhibou
# Processing Record 174 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bengkulu
# Processing Record 175 | dashitou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dashitou
# Processing Record 176 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vardo
# Processing Record 177 | aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=aksarka
# Processing Record 178 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tasiilaq
# Processing Record 179 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tautira
# Processing Record 180 | guapi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=guapi
# Processing Record 181 | abbeville
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=abbeville
# Processing Record 182 | saint-ambroise
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint-ambroise
# Processing Record 183 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=faya
# Processing Record 184 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lompoc
# Processing Record 185 | manaure
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=manaure
# Processing Record 186 | belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=belmonte
# Processing Record 187 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vila+franca+do+campo
# Processing Record 188 | el alto
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=el+alto
# Processing Record 189 | stekolnyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=stekolnyy
# Processing Record 190 | houston
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=houston
# Processing Record 191 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chuy
# Processing Record 192 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=khatanga
# Processing Record 193 | masingbi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=masingbi
# Processing Record 194 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=muros
# Processing Record 195 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=praia+da+vitoria
# Processing Record 196 | sechura
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sechura
# Processing Record 197 | kisaran
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kisaran
# Processing Record 198 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=acapulco
# Processing Record 199 | naberera
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=naberera
# Processing Record 200 | torrevieja
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=torrevieja
# Processing Record 201 | banepa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=banepa
# Processing Record 202 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=leshukonskoye
# Processing Record 203 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+moresby
# Processing Record 204 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=verkhoyansk
# Processing Record 205 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=westport
# Processing Record 206 | visnes
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=visnes
# Processing Record 207 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=namatanai
# Processing Record 208 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lagoa
# Processing Record 209 | russell
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=russell
# Processing Record 210 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=buraydah
# Processing Record 211 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=carnarvon
# Processing Record 212 | mkushi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mkushi
# Processing Record 213 | toungoo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=toungoo
# Processing Record 214 | tukums
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tukums
# Processing Record 215 | potosi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=potosi
# Processing Record 216 | ossora
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ossora
# Processing Record 217 | lexington
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lexington
# Processing Record 218 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=alofi
# Processing Record 219 | parakan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=parakan
# Processing Record 220 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sao+felix+do+xingu
# Processing Record 221 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kirakira
# Processing Record 222 | pavino
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pavino
# Processing Record 223 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=new+norfolk
# Processing Record 224 | yima
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yima
# Processing Record 225 | mwingi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mwingi
# Processing Record 226 | meyungs
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=meyungs
# Processing Record 227 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bethel
# Processing Record 228 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saldanha
# Processing Record 229 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sentyabrskiy
# Processing Record 230 | kudat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kudat
# Processing Record 231 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sola
# Processing Record 232 | bulawayo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bulawayo
# Processing Record 233 | candolim
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=candolim
# Processing Record 234 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=coihaique
# Processing Record 235 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=the+valley
# Processing Record 236 | calatayud
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=calatayud
# Processing Record 237 | sibenik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sibenik
# Processing Record 238 | katangli
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=katangli
# Processing Record 239 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=trincomalee
# Processing Record 240 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+luis
# Processing Record 241 | lamar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lamar
# Processing Record 242 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=iqaluit
# Processing Record 243 | priiskovyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=priiskovyy
# Processing Record 244 | poltavka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=poltavka
# Processing Record 245 | mattru
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mattru
# Processing Record 246 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mount+gambier
# Processing Record 247 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bereda
# Processing Record 248 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=norman+wells
# Processing Record 249 | pozega
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pozega
# Processing Record 250 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tiksi
# Processing Record 251 | troitskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=troitskoye
# Processing Record 252 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tasbuget
# Processing Record 253 | matsusaka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=matsusaka
# Processing Record 254 | dovers
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dovers
# Processing Record 255 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fortuna
# Processing Record 256 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=northam
# Processing Record 257 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tiznit
# Processing Record 258 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=klaksvik
# Processing Record 259 | pandan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pandan
# Processing Record 260 | orsta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=orsta
# Processing Record 261 | katobu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=katobu
# Processing Record 262 | vaijapur
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vaijapur
# Processing Record 263 | bafra
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bafra
# Processing Record 264 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pangnirtung
# Processing Record 265 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+patricio
# Processing Record 266 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hami
# Processing Record 267 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hamilton
# Processing Record 268 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sao+joao+da+barra
# Processing Record 269 | phrai bung
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=phrai+bung
# Processing Record 270 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jacareacanga
# Processing Record 271 | magdiwang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=magdiwang
# Processing Record 272 | nosy varika
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nosy+varika
# Processing Record 273 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=erenhot
# Processing Record 274 | svetlaya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=svetlaya
# Processing Record 275 | ampanihy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ampanihy
# Processing Record 276 | huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=huarmey
# Processing Record 277 | uyuni
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=uyuni
# Processing Record 278 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=umm+kaddadah
# Processing Record 279 | rawah
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rawah
# Processing Record 280 | panjwin
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=panjwin
# Processing Record 281 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=narsaq
# Processing Record 282 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=labuhan
# Processing Record 283 | sandwick
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sandwick
# Processing Record 284 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tura
# Processing Record 285 | znamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=znamenskoye
# Processing Record 286 | surt
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=surt
# Processing Record 287 | carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=carutapera
# Processing Record 288 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=angoche
# Processing Record 289 | takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=takoradi
# Processing Record 290 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=berlevag
# Processing Record 291 | karaul
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=karaul
# Processing Record 292 | alotau
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=alotau
# Processing Record 293 | waitati
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=waitati
# Processing Record 294 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lorengau
# Processing Record 295 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yerbogachen
# Processing Record 296 | erzurum
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=erzurum
# Processing Record 297 | rockland
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rockland
# Processing Record 298 | manacapuru
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=manacapuru
# Processing Record 299 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+lincoln
# Processing Record 300 | fare
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fare
# Processing Record 301 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tomatlan
# Processing Record 302 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=leningradskiy
# Processing Record 303 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=salalah
# Processing Record 304 | bonfim
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bonfim
# Processing Record 305 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=batemans+bay
# Processing Record 306 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=gat
# Processing Record 307 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=paamiut
# Processing Record 308 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hervey+bay
# Processing Record 309 | newport
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=newport
# Processing Record 310 | luganville
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=luganville
# Processing Record 311 | suluq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=suluq
# Processing Record 312 | tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tiarei
# Processing Record 313 | butterworth
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=butterworth
# Processing Record 314 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=samarai
# Processing Record 315 | saint marys
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+marys
# Processing Record 316 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=broome
# Processing Record 317 | balakovo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=balakovo
# Processing Record 318 | saint stephen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+stephen
# Processing Record 319 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=talnakh
# ...
# Processing Record 503 | petropavlovka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=petropavlovka
# Processing Record 504 | ambulu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ambulu
# Processing Record 505 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bay+roberts
# Processing Record 506 | wajir
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=wajir
# Processing Record 507 | suba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=suba
# Processing Record 508 | mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mokhsogollokh
# Processing Record 509 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+macquarie
# Processing Record 510 | panaba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=panaba
# Processing Record 511 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dunedin
# Processing Record 512 | ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ostersund
# Processing Record 513 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kapoeta
# Processing Record 514 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=oktyabrskiy
# Processing Record 515 | teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=teguldet
# Processing Record 516 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pangkalanbuun
# Processing Record 517 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rio+gallegos
# Processing Record 518 | west wendover
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=west+wendover
# Processing Record 519 | tougan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tougan
# Processing Record 520 | san rafael
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+rafael
# Processing Record 521 | owando
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=owando
# Processing Record 522 | mokhotlong
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mokhotlong
# Processing Record 523 | weymouth
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=weymouth
# Processing Record 524 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ixtapa
# Processing Record 525 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=alice+springs
# Processing Record 526 | casablanca
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=casablanca
# Processing Record 527 | cradock
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cradock
# Processing Record 528 | sikonge
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sikonge
# Processing Record 529 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=moose+factory
# Processing Record 530 | chagda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chagda
# Processing Record 531 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=puerto+colombia
# Processing Record 532 | oga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=oga
# Processing Record 533 | iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=iskateley
# Processing Record 534 | kidal
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kidal
# Processing Record 535 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=thinadhoo
# Processing Record 536 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lolua
# Processing Record 537 | karakol
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=karakol
# Processing Record 538 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=puerto+escondido
# Processing Record 539 | darhan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=darhan
# Processing Record 540 | imeni poliny osipenko
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=imeni+poliny+osipenko
# Processing Record 541 | birjand
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=birjand
# Processing Record 542 | nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nuuk
# Processing Record 543 | altay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=altay
# Processing Record 544 | road town
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=road+town
# Processing Record 545 | pa daet
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pa+daet
# Processing Record 546 | kamen-rybolov
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kamen-rybolov
# Processing Record 547 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ust-maya
# Processing Record 548 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sao+jose+da+coroa+grande
# Processing Record 549 | khash
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=khash
# Processing Record 550 | pizarro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pizarro
# Processing Record 551 | sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sumbe
# Processing Record 552 | owatonna
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=owatonna
# Processing Record 553 | paka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=paka
# Processing Record 554 | lima
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lima
# Processing Record 555 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=beloha
# Processing Record 556 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=namibe
# Processing Record 557 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint-leu
# Processing Record 558 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ambilobe
# Processing Record 559 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bonavista
# Processing Record 560 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=margate
# Processing Record 561 | arman
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=arman
# Processing Record 562 | waterloo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=waterloo
# Processing Record 563 | iwanai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=iwanai
# Processing Record 564 | ziyang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ziyang
# Processing Record 565 | sapao
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sapao
# Processing Record 566 | atagay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=atagay
# Processing Record 567 | parambu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=parambu
# Processing Record 568 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sept-iles
# Processing Record 569 | basco
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=basco
# Processing Record 570 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cap+malheureux
# Processing Record 571 | mahadday weyne
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mahadday+weyne
# Processing Record 572 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=beringovskiy
# Processing Record 573 | bargal
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bargal
# Processing Record 574 | deniliquin
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=deniliquin
# Processing Record 575 | dinard
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dinard
# Processing Record 576 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tombouctou
# Processing Record 577 | visby
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=visby
# Processing Record 578 | sibu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sibu
# Processing Record 579 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=la+ronge
# Processing Record 580 | danjiangkou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=danjiangkou
# Processing Record 581 | kone
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kone
# Processing Record 582 | bahia honda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bahia+honda
# Processing Record 583 | otradnoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=otradnoye
# Processing Record 584 | brokopondo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=brokopondo
# Processing Record 585 | canyon lake
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=canyon+lake
# Processing Record 586 | terni
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=terni
# Processing Record 587 | willowmore
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=willowmore
# Processing Record 588 | kimbe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kimbe
# Processing Record 589 | chase
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chase
# Processing Record 590 | mokrous
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mokrous
# Processing Record 591 | baiao
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=baiao
# Processing Record 592 | baker city
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=baker+city
# Processing Record 593 | fort myers beach
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fort+myers+beach
# Processing Record 594 | camocim
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=camocim
# Processing Record 595 | buldana
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=buldana
# Processing Record 596 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=klyuchi
# Processing Record 597 | ibotirama
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ibotirama
# Processing Record 598 | sao domingos do maranhao
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sao+domingos+do+maranhao
# Processing Record 599 | torbat-e jam
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=torbat-e+jam
# Processing Record 600 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hasaki
# Processing Record 601 | amga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=amga
# Processing Record 602 | lydenburg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lydenburg
# Processing Record 603 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sosnovo-ozerskoye
# Processing Record 604 | iquitos
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=iquitos
# Processing Record 605 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=aklavik
# Processing Record 606 | farmington
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=farmington
# Processing Record 607 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nome
# Processing Record 608 | manokwari
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=manokwari
# Processing Record 609 | shelburne
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=shelburne
# Processing Record 610 | mwanza
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mwanza
# Processing Record 611 | terekli-mekteb
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=terekli-mekteb

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
list_of_cities.reset_index(drop=True, inplace=True)
list_of_cities.to_csv("City_Weather_data.csv")
list_of_cities.head(25)
# Out:
#                city  Cloudiness Country  Humidity  Latitude  Longitude  \
# 0    krasnozerskoye         0.0      RU      69.0     53.98      79.24
# 1             kutum        76.0      SD      38.0     14.20      24.66
# 2           rikitea        64.0      PF     100.0    -23.12    -134.97
# 3           ushuaia        40.0      AR      65.0    -54.81     -68.31
# 4       port alfred        76.0      ZA      92.0    -33.59      26.89
# 5            albany        40.0      US      86.0     42.65     -73.75
# 6          cidreira        88.0      BR      94.0    -30.17     -50.22
# 7           mataura        44.0      NZ      70.0    -46.19     168.86
# 8             tabou        48.0      CI     100.0      4.42      -7.36
# 9            kupang        20.0      ID      66.0    -10.16     123.60
# 10         victoria        75.0      BN      83.0      5.28     115.24
# 11  arraial do cabo        80.0      BR      99.0    -22.97     -42.02
# 12          uruzgan         0.0      AF      29.0     32.93      66.63
# 13     punta arenas        90.0      CL      87.0    -53.16     -70.91
# 14     longyearbyen        75.0      NO      74.0     78.22      15.63
# 15        kabanjahe        36.0      ID      88.0      3.10      98.49
# 16           atuona        24.0      PF     100.0     -9.80    -139.03
# 17        upernavik         0.0      GL     100.0     72.79     -56.15
# 18            semey         0.0      KZ      48.0     50.41      80.25
# 19             hilo        90.0      US      94.0     19.71    -155.08
# 20            altea         0.0      ES      87.0     38.60      -0.05
# 21        kavaratti         0.0      IN     100.0     10.57      72.64
# 22            vaini         0.0      IN      67.0     15.34      74.49
# 23         upington         0.0      ZA      17.0    -28.46      21.24
# 24   cabo san lucas         5.0      MX      73.0     22.89    -109.91
#
#     Max Temperature  Wind Speed
# 0             46.34        7.96
# 1             75.14        4.27
# 2             71.68       10.20
# 3             44.60        2.71
# 4             69.52       10.65
# 5             33.80        3.83
# 6             65.96        7.18
# 7             53.68        6.06
# 8             79.42        3.38
# 9             89.68        6.17
# 10            84.20        3.36
# 11            70.96       17.69
# 12            57.37        2.71
# 13            44.60       14.99
# 14            28.40       11.41
# 15            75.46        2.04
# 16            79.73       15.46
# 17            17.18        8.97
# 18            50.48        9.86
# 19            75.20        5.82
# 20            55.40        5.82
# 21            84.68        5.61
# 22            84.68        8.52
# 23            71.60        2.93
# 24            75.20        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Plot settings
def set_plot_prop(x_title,x_lim,y_title):
    plt.title(f"{x_title} vs {y_title}")
    plt.ylabel(y_title)
    plt.xlabel(x_title)
    plt.grid(True)
    plt.xlim(x_lim)

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Max Temperature",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Temperature (F)")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Temperature")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Humidity",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Humidity")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Humidity")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Cloudiness",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Cloudiness")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Wind Speed",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Wind Speed")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Wind Speed")
plt.show()

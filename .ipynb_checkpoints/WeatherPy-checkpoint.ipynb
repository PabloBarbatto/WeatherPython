# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import requests

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries= []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        

# Print the city count to confirm sufficient count
list_of_cities = pd.DataFrame({"city" : cities})
list_of_cities
# Out:
#                 city
# 0           tamiahua
# 1            salalah
# 2           tasiilaq
# 3            ushuaia
# 4        mujiayingzi
# 5            rikitea
# 6         sao filipe
# 7               poum
# 8             zhuhai
# 9          upernavik
# 10        bredasdorp
# 11        maningrida
# 12        nikolskoye
# 13              lebu
# 14        port hardy
# 15           mataura
# 16               bud
# 17            barrow
# 18          victoria
# 19      komsomolskiy
# 20       provideniya
# 21             praia
# 22          okmulgee
# 23       port alfred
# 24      norman wells
# 25       caraballeda
# 26          cabedelo
# 27            luanda
# 28           svetlyy
# 29         jamestown
# ..               ...
# 563        spearfish
# 564            adrar
# 565             yaan
# 566         tarudant
# 567          peniche
# 568         rosarito
# 569           pangoa
# 570             dole
# 571            beira
# 572         ngunguru
# 573             mega
# 574           kytlym
# 575          sorland
# 576          armeria
# 577          rungata
# 578        venezuela
# 579   nuevo progreso
# 580  fort saint john
# 581          chitral
# 582       san miguel
# 583          maykain
# 584         acuitzio
# 585        kyrylivka
# 586            conde
# 587              leh
# 588          sanming
# 589          huanren
# 590       turukhansk
# 591         lakatoro
# 592          ternate
#
# [593 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setting up values for OpenWeatherMap API calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

app_id = api_key

params = { "appid" :app_id,"units":"Imperial" }
row_count = 0
for index,row in list_of_cities.iterrows():
    params["q"] =f'{row["city"]}'
    print(f"Processing Record {row_count} | {params['q']}")
    city_weather_resp = requests.get(base_url,params)
    print(city_weather_resp.url)
    city_weather_resp  = city_weather_resp.json()
    try:
        list_of_cities.set_value(index,"Cloudiness",city_weather_resp.get("clouds",{}).get("all"))
        list_of_cities.set_value(index,"Country",city_weather_resp.get("sys",{}).get("country"))
        list_of_cities.set_value(index,"Date",city_weather_resp.get("dt",{}))
        list_of_cities.set_value(index,"Humidity",city_weather_resp.get("main",{}).get("humidity"))
        list_of_cities.set_value(index,"Latitude",city_weather_resp.get("coord",{}).get("lat"))
        list_of_cities.set_value(index,"Longitude",city_weather_resp.get("coord",{}).get("lon"))
        list_of_cities.set_value(index,"Max Temperature",city_weather_resp.get("main",{}).get("temp_max"))
        list_of_cities.set_value(index,"Wind Speed",city_weather_resp.get("wind",{}).get("speed"))
        row_count = row_count + 1
    except(ValueError, KeyError , IndexError):
        print("missing result...... skiping to next city on list")
# Out:
# Processing Record 0 | tamiahua
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tamiahua
# Processing Record 1 | salalah
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\pablo\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=salalah
# Processing Record 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tasiilaq
# Processing Record 3 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ushuaia
# Processing Record 4 | mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mujiayingzi
# Processing Record 5 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rikitea
# Processing Record 6 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sao+filipe
# Processing Record 7 | poum
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=poum
# Processing Record 8 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=zhuhai
# Processing Record 9 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=upernavik
# Processing Record 10 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bredasdorp
# Processing Record 11 | maningrida
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=maningrida
# Processing Record 12 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nikolskoye
# Processing Record 13 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lebu
# Processing Record 14 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+hardy
# Processing Record 15 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mataura
# Processing Record 16 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bud
# Processing Record 17 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=barrow
# Processing Record 18 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=victoria
# Processing Record 19 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=komsomolskiy
# Processing Record 20 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=provideniya
# Processing Record 21 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=praia
# Processing Record 22 | okmulgee
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=okmulgee
# Processing Record 23 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+alfred
# Processing Record 24 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=norman+wells
# Processing Record 25 | caraballeda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=caraballeda
# Processing Record 26 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cabedelo
# Processing Record 27 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=luanda
# Processing Record 28 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=svetlyy
# missing result...... skiping to next city on list
# Processing Record 28 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jamestown
# Processing Record 29 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=barentsburg
# missing result...... skiping to next city on list
# Processing Record 29 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dunedin
# Processing Record 30 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=longyearbyen
# Processing Record 31 | balykshi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=balykshi
# missing result...... skiping to next city on list
# Processing Record 31 | corinto
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=corinto
# Processing Record 32 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pacific+grove
# Processing Record 33 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saldanha
# Processing Record 34 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cape+town
# Processing Record 35 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mar+del+plata
# Processing Record 36 | dawei
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dawei
# Processing Record 37 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=aklavik
# Processing Record 38 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kungurtug
# Processing Record 39 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hasaki
# Processing Record 40 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kununurra
# Processing Record 41 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=qaanaaq
# Processing Record 42 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=castro
# Processing Record 43 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ponta+do+sol
# Processing Record 44 | ambon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ambon
# Processing Record 45 | coos bay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=coos+bay
# Processing Record 46 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+george
# Processing Record 47 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fortuna
# Processing Record 48 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vao
# Processing Record 49 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=taolanaro
# missing result...... skiping to next city on list
# Processing Record 49 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hirara
# Processing Record 50 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sentyabrskiy
# missing result...... skiping to next city on list
# Processing Record 50 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hermanus
# Processing Record 51 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tuktoyaktuk
# Processing Record 52 | malakal
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=malakal
# missing result...... skiping to next city on list
# Processing Record 52 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saskylakh
# Processing Record 53 | atikokan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=atikokan
# Processing Record 54 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=albany
# Processing Record 55 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=busselton
# Processing Record 56 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lorengau
# Processing Record 57 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=westport
# Processing Record 58 | black river
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=black+river
# Processing Record 59 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hilo
# Processing Record 60 | pombas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pombas
# Processing Record 61 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=omboue
# Processing Record 62 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hualmay
# Processing Record 63 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=east+london
# Processing Record 64 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dikson
# Processing Record 65 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+elizabeth
# Processing Record 66 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=prince+rupert
# Processing Record 67 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=belushya+guba
# missing result...... skiping to next city on list
# Processing Record 67 | mao
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mao
# Processing Record 68 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bluff
# Processing Record 69 | forio
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=forio
# Processing Record 70 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cabo+san+lucas
# Processing Record 71 | kindu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kindu
# Processing Record 72 | manta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=manta
# Processing Record 73 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=samusu
# missing result...... skiping to next city on list
# Processing Record 73 | togur
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=togur
# Processing Record 74 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=grand+river+south+east
# missing result...... skiping to next city on list
# Processing Record 74 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tiznit
# Processing Record 75 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bambous+virieux
# Processing Record 76 | azanka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=azanka
# Processing Record 77 | port said
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+said
# Processing Record 78 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=keti+bandar
# Processing Record 79 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chuy
# Processing Record 80 | waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=waingapu
# Processing Record 81 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mys+shmidta
# missing result...... skiping to next city on list
# Processing Record 81 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=puerto+ayora
# Processing Record 82 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ostrovnoy
# Processing Record 83 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yenagoa
# Processing Record 84 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=antofagasta
# Processing Record 85 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=zhanaozen
# Processing Record 86 | shieli
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=shieli
# Processing Record 87 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+hedland
# Processing Record 88 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=punta+arenas
# Processing Record 89 | pedernales
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pedernales
# Processing Record 90 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vaini
# Processing Record 91 | anahuac
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=anahuac
# Processing Record 92 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=attawapiskat
# missing result...... skiping to next city on list
# Processing Record 92 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=laguna
# Processing Record 93 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=beringovskiy
# Processing Record 94 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=illoqqortoormiut
# missing result...... skiping to next city on list
# Processing Record 94 | ayan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ayan
# Processing Record 95 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yeppoon
# Processing Record 96 | wonthaggi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=wonthaggi
# Processing Record 97 | vryburg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vryburg
# Processing Record 98 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=codrington
# Processing Record 99 | grand centre
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=grand+centre
# missing result...... skiping to next city on list
# Processing Record 99 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chokurdakh
# Processing Record 100 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=leshukonskoye
# Processing Record 101 | imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=imbituba
# Processing Record 102 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=thompson
# Processing Record 103 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bethel
# Processing Record 104 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rio+grande
# Processing Record 105 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=luang+prabang
# Processing Record 106 | bintulu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bintulu
# Processing Record 107 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hobart
# Processing Record 108 | lephepe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lephepe
# missing result...... skiping to next city on list
# Processing Record 108 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ilulissat
# Processing Record 109 | lebedinyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lebedinyy
# Processing Record 110 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dingle
# Processing Record 111 | sile
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sile
# Processing Record 112 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=port+blair
# Processing Record 113 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ancud
# Processing Record 114 | aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=aksarka
# Processing Record 115 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=berlevag
# Processing Record 116 | shanhetun
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=shanhetun
# Processing Record 117 | tancanhuitz
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tancanhuitz
# missing result...... skiping to next city on list
# Processing Record 117 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kapaa
# Processing Record 118 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sur
# Processing Record 119 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cam+ranh
# Processing Record 120 | nzerekore
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nzerekore
# Processing Record 121 | juneau
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=juneau
# Processing Record 122 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=airai
# Processing Record 123 | khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=khandyga
# Processing Record 124 | belfast
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=belfast
# Processing Record 125 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+carlos+de+bariloche
# Processing Record 126 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+anthony
# Processing Record 127 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tsihombe
# missing result...... skiping to next city on list
# Processing Record 127 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ruatoria
# missing result...... skiping to next city on list
# Processing Record 127 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=georgetown
# Processing Record 128 | nioro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nioro
# Processing Record 129 | khonuu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=khonuu
# missing result...... skiping to next city on list
# Processing Record 129 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=touros
# Processing Record 130 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=butaritari
# Processing Record 131 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tiksi
# Processing Record 132 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tasbuget
# missing result...... skiping to next city on list
# Processing Record 132 | poddorye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=poddorye
# Processing Record 133 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pevek
# Processing Record 134 | cairns
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cairns
# Processing Record 135 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=new+norfolk
# Processing Record 136 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=aykhal
# Processing Record 137 | sao borja
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sao+borja
# Processing Record 138 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tilichiki
# Processing Record 139 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mahebourg
# Processing Record 140 | pechenga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pechenga
# Processing Record 141 | vredendal
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=vredendal
# Processing Record 142 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint-philippe
# Processing Record 143 | jiaohe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jiaohe
# Processing Record 144 | huilong
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=huilong
# Processing Record 145 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=naze
# Processing Record 146 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sungaipenuh
# Processing Record 147 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saleaula
# missing result...... skiping to next city on list
# Processing Record 147 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=umzimvubu
# missing result...... skiping to next city on list
# Processing Record 147 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=souillac
# Processing Record 148 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=khatanga
# Processing Record 149 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mandalgovi
# Processing Record 150 | uvat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=uvat
# Processing Record 151 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=atuona
# Processing Record 152 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=okhotsk
# Processing Record 153 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kodinsk
# Processing Record 154 | basco
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=basco
# Processing Record 155 | paducah
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=paducah
# Processing Record 156 | sozimskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sozimskiy
# Processing Record 157 | point pedro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=point+pedro
# Processing Record 158 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hobyo
# Processing Record 159 | labuan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=labuan
# Processing Record 160 | teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=teguldet
# Processing Record 161 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lolua
# missing result...... skiping to next city on list
# Processing Record 161 | nicoya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nicoya
# Processing Record 162 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kodiak
# Processing Record 163 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=los+llanos+de+aridane
# Processing Record 164 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=severo-kurilsk
# Processing Record 165 | mollendo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mollendo
# Processing Record 166 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=avarua
# Processing Record 167 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hami
# Processing Record 168 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nanortalik
# Processing Record 169 | scottsbluff
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=scottsbluff
# Processing Record 170 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=iqaluit
# Processing Record 171 | sheboygan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sheboygan
# Processing Record 172 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lata
# Processing Record 173 | bemidji
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bemidji
# Processing Record 174 | kushima
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kushima
# Processing Record 175 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=esperance
# Processing Record 176 | sugar land
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sugar+land
# Processing Record 177 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rocha
# Processing Record 178 | bafia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bafia
# Processing Record 179 | karpogory
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=karpogory
# Processing Record 180 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=portland
# Processing Record 181 | eidsvag
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=eidsvag
# Processing Record 182 | agirish
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=agirish
# Processing Record 183 | acari
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=acari
# Processing Record 184 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lagoa
# Processing Record 185 | ilebo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ilebo
# Processing Record 186 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pisco
# Processing Record 187 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=qasigiannguit
# Processing Record 188 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yellowknife
# Processing Record 189 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=qaqortoq
# Processing Record 190 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=palabuhanratu
# missing result...... skiping to next city on list
# Processing Record 190 | sedelnikovo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sedelnikovo
# missing result...... skiping to next city on list
# Processing Record 190 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=almaznyy
# Processing Record 191 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kasongo-lunda
# Processing Record 192 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=alta+floresta
# Processing Record 193 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=olafsvik
# missing result...... skiping to next city on list
# Processing Record 193 | cotonou
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cotonou
# Processing Record 194 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=constitucion
# Processing Record 195 | bara
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bara
# Processing Record 196 | temiscaming
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=temiscaming
# Processing Record 197 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+patricio
# Processing Record 198 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=erenhot
# Processing Record 199 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nanakuli
# Processing Record 200 | agadez
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=agadez
# Processing Record 201 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sisimiut
# Processing Record 202 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=carnarvon
# Processing Record 203 | tambul
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tambul
# missing result...... skiping to next city on list
# Processing Record 203 | gondanglegi
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=gondanglegi
# Processing Record 204 | muroto
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=muroto
# Processing Record 205 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=amderma
# missing result...... skiping to next city on list
# Processing Record 205 | cuiluan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cuiluan
# Processing Record 206 | wilmington
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=wilmington
# Processing Record 207 | wulanhaote
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=wulanhaote
# missing result...... skiping to next city on list
# Processing Record 207 | zharkent
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=zharkent
# Processing Record 208 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=alice+springs
# Processing Record 209 | beni mazar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=beni+mazar
# Processing Record 210 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hithadhoo
# Processing Record 211 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tuatapere
# Processing Record 212 | tongren
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tongren
# Processing Record 213 | morena
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=morena
# Processing Record 214 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tumannyy
# missing result...... skiping to next city on list
# Processing Record 214 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=puerto+colombia
# Processing Record 215 | pontianak
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pontianak
# Processing Record 216 | winneba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=winneba
# Processing Record 217 | the pas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=the+pas
# Processing Record 218 | calvinia
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=calvinia
# Processing Record 219 | kalemie
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kalemie
# Processing Record 220 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kavaratti
# Processing Record 221 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=arraial+do+cabo
# Processing Record 222 | toliary
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=toliary
# missing result...... skiping to next city on list
# Processing Record 222 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cidreira
# Processing Record 223 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=caravelas
# Processing Record 224 | kozluk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kozluk
# Processing Record 225 | tanete
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tanete
# Processing Record 226 | campina verde
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=campina+verde
# Processing Record 227 | nakamura
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nakamura
# Processing Record 228 | massaguet
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=massaguet
# Processing Record 229 | susurluk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=susurluk
# Processing Record 230 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=grindavik
# Processing Record 231 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=coihaique
# Processing Record 232 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=boca+do+acre
# Processing Record 233 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sinnamary
# Processing Record 234 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kahului
# Processing Record 235 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=the+valley
# Processing Record 236 | artyom
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=artyom
# Processing Record 237 | barcelos
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=barcelos
# Processing Record 238 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=havelock
# Processing Record 239 | nara
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nara
# Processing Record 240 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=leningradskiy
# Processing Record 241 | kaduy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kaduy
# Processing Record 242 | paijan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=paijan
# Processing Record 243 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=oranjemund
# Processing Record 244 | seddon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=seddon
# Processing Record 245 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=flin+flon
# Processing Record 246 | kieta
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kieta
# Processing Record 247 | ginir
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ginir
# Processing Record 248 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=srednekolymsk
# Processing Record 249 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cap+malheureux
# Processing Record 250 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=isangel
# Processing Record 251 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=half+moon+bay
# Processing Record 252 | kupino
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kupino
# Processing Record 253 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mehamn
# Processing Record 254 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sioux+lookout
# Processing Record 255 | segarcea vale
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=segarcea+vale
# Processing Record 256 | rawlins
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rawlins
# Processing Record 257 | dongzhen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dongzhen
# Processing Record 258 | magburaka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=magburaka
# Processing Record 259 | pitea
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pitea
# Processing Record 260 | nova vodolaha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nova+vodolaha
# Processing Record 261 | karaul
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=karaul
# missing result...... skiping to next city on list
# Processing Record 261 | koslan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=koslan
# Processing Record 262 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bathsheba
# Processing Record 263 | ocampo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ocampo
# Processing Record 264 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=najran
# Processing Record 265 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bilibino
# Processing Record 266 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=namibe
# Processing Record 267 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sitka
# Processing Record 268 | yavas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yavas
# Processing Record 269 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hambantota
# Processing Record 270 | montepuez
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=montepuez
# Processing Record 271 | leninogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=leninogorsk
# Processing Record 272 | pimentel
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pimentel
# Processing Record 273 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=faya
# Processing Record 274 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=te+anau
# Processing Record 275 | bolonchen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bolonchen
# missing result...... skiping to next city on list
# Processing Record 275 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=katsuura
# ...
# Processing Record 434 | nguiu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nguiu
# missing result...... skiping to next city on list
# Processing Record 434 | bushehr
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bushehr
# Processing Record 435 | longyan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=longyan
# Processing Record 436 | harper
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=harper
# Processing Record 437 | san angelo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+angelo
# Processing Record 438 | liverpool
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=liverpool
# Processing Record 439 | gazojak
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=gazojak
# Processing Record 440 | pravec
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pravec
# missing result...... skiping to next city on list
# Processing Record 440 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=geraldton
# Processing Record 441 | ayagoz
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ayagoz
# Processing Record 442 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hamilton
# Processing Record 443 | jumla
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jumla
# Processing Record 444 | olinda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=olinda
# Processing Record 445 | rehti
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rehti
# Processing Record 446 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=valparaiso
# Processing Record 447 | lampazos de naranjo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lampazos+de+naranjo
# Processing Record 448 | senica
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=senica
# Processing Record 449 | tubruq
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tubruq
# missing result...... skiping to next city on list
# Processing Record 449 | pochinki
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pochinki
# Processing Record 450 | jinka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jinka
# Processing Record 451 | kuching
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kuching
# Processing Record 452 | oum hadjer
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=oum+hadjer
# Processing Record 453 | hun
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=hun
# Processing Record 454 | lahad datu
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lahad+datu
# Processing Record 455 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=karratha
# Processing Record 456 | umkomaas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=umkomaas
# Processing Record 457 | fukue
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fukue
# Processing Record 458 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=solovetskiy
# missing result...... skiping to next city on list
# Processing Record 458 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=santa+maria
# Processing Record 459 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=flinders
# Processing Record 460 | mashhad
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mashhad
# Processing Record 461 | newport
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=newport
# Processing Record 462 | bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bodden+town
# Processing Record 463 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=maceio
# Processing Record 464 | nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nyurba
# Processing Record 465 | morondava
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=morondava
# Processing Record 466 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kapuskasing
# Processing Record 467 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=anadyr
# Processing Record 468 | borgarnes
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=borgarnes
# Processing Record 469 | arcata
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=arcata
# Processing Record 470 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=cayenne
# Processing Record 471 | tucuma
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tucuma
# missing result...... skiping to next city on list
# Processing Record 471 | pasni
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pasni
# Processing Record 472 | iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=iskateley
# Processing Record 473 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=klaksvik
# Processing Record 474 | great yarmouth
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=great+yarmouth
# Processing Record 475 | nalut
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nalut
# Processing Record 476 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=raudeberg
# Processing Record 477 | jinchang
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=jinchang
# Processing Record 478 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kamenskoye
# missing result...... skiping to next city on list
# Processing Record 478 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lasa
# Processing Record 479 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bereda
# Processing Record 480 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ixtapa
# Processing Record 481 | carlsbad
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=carlsbad
# Processing Record 482 | bouar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bouar
# Processing Record 483 | zhanatas
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=zhanatas
# missing result...... skiping to next city on list
# Processing Record 483 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=baruun-urt
# Processing Record 484 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mount+isa
# Processing Record 485 | barcelona
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=barcelona
# Processing Record 486 | saint cloud
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=saint+cloud
# Processing Record 487 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=deputatskiy
# Processing Record 488 | rehoboth
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rehoboth
# Processing Record 489 | kasra
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kasra
# missing result...... skiping to next city on list
# Processing Record 489 | porto velho
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=porto+velho
# Processing Record 490 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=thinadhoo
# Processing Record 491 | kasongo
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kasongo
# Processing Record 492 | yumen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yumen
# Processing Record 493 | bowen
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=bowen
# Processing Record 494 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nhulunbuy
# Processing Record 495 | andra
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=andra
# Processing Record 496 | austin
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=austin
# Processing Record 497 | dukat
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dukat
# Processing Record 498 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=acapulco
# Processing Record 499 | grants
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=grants
# Processing Record 500 | minab
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=minab
# Processing Record 501 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=gushikawa
# Processing Record 502 | spearfish
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=spearfish
# Processing Record 503 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=adrar
# Processing Record 504 | yaan
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=yaan
# Processing Record 505 | tarudant
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=tarudant
# missing result...... skiping to next city on list
# Processing Record 505 | peniche
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=peniche
# Processing Record 506 | rosarito
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rosarito
# Processing Record 507 | pangoa
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=pangoa
# Processing Record 508 | dole
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=dole
# Processing Record 509 | beira
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=beira
# Processing Record 510 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ngunguru
# Processing Record 511 | mega
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=mega
# Processing Record 512 | kytlym
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kytlym
# missing result...... skiping to next city on list
# Processing Record 512 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sorland
# Processing Record 513 | armeria
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=armeria
# Processing Record 514 | rungata
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=rungata
# missing result...... skiping to next city on list
# Processing Record 514 | venezuela
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=venezuela
# Processing Record 515 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=nuevo+progreso
# Processing Record 516 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=fort+saint+john
# missing result...... skiping to next city on list
# Processing Record 516 | chitral
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=chitral
# Processing Record 517 | san miguel
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=san+miguel
# Processing Record 518 | maykain
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=maykain
# missing result...... skiping to next city on list
# Processing Record 518 | acuitzio
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=acuitzio
# Processing Record 519 | kyrylivka
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=kyrylivka
# Processing Record 520 | conde
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=conde
# Processing Record 521 | leh
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=leh
# Processing Record 522 | sanming
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=sanming
# Processing Record 523 | huanren
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=huanren
# Processing Record 524 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=turukhansk
# Processing Record 525 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=lakatoro
# Processing Record 526 | ternate
# http://api.openweathermap.org/data/2.5/weather?appid=19b32067ed32e919fafe0c91f8bf0faa&units=Imperial&q=ternate

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
list_of_cities =list_of_cities.dropna()
list_of_cities.reset_index(drop=True, inplace=True)
list_of_cities['Date'] = list_of_cities["Date"].astype('int64', copy=False)
list_of_cities.to_csv("City_Weather_data.csv")
list_of_cities
# Out:
#                city  Cloudiness Country        Date  Humidity  Latitude  \
# 0          tamiahua        92.0      MX  1540653539     100.0     21.28
# 1           salalah        20.0      OM  1540648200      78.0     17.01
# 2          tasiilaq        92.0      GL  1540651800     100.0     65.61
# 3           ushuaia        75.0      AR  1540648800      76.0    -54.81
# 4       mujiayingzi        36.0      CN  1540653539      43.0     42.12
# 5           rikitea        48.0      PF  1540653540     100.0    -23.12
# 6        sao filipe        20.0      CV  1540653540      93.0     14.90
# 7              poum         0.0      MK  1540653540      44.0     41.28
# 8            zhuhai         0.0      CN  1540648800      38.0     40.71
# 9         upernavik        92.0      GL  1540653541     100.0     72.79
# 10       bredasdorp        20.0      ZA  1540648800      60.0    -34.53
# 11       maningrida        20.0      AU  1540653541      75.0    -12.05
# 12       nikolskoye        75.0      RU  1540650600      80.0     59.70
# 13             lebu         0.0      ET  1540653542      34.0      8.96
# 14       port hardy        20.0      CA  1540652400      93.0     50.70
# 15          mataura        88.0      NZ  1540653542     100.0    -46.19
# 16              bud        40.0      NO  1540651800      86.0     62.91
# 17           barrow        20.0      AR  1540653546      77.0    -38.31
# 18         victoria        90.0      BN  1540652400      88.0      5.28
# 19     komsomolskiy        92.0      RU  1540653546      92.0     67.55
# 20      provideniya         0.0      RU  1540653495     100.0     64.42
# 21            praia        75.0      BR  1540648800      69.0    -20.25
# 22         okmulgee         1.0      US  1540652100      77.0     35.62
# 23      port alfred        56.0      ZA  1540653547      79.0    -33.59
# 24     norman wells        90.0      CA  1540652400     100.0     65.28
# 25      caraballeda         0.0      VE  1540653548      92.0     10.61
# 26         cabedelo        40.0      BR  1540648800      51.0     -6.97
# 27           luanda        20.0      AO  1540652400      66.0     -8.83
# 28        jamestown        92.0      AU  1540653409      68.0    -33.21
# 29          dunedin        92.0      NZ  1540653549     100.0    -45.87
# ..              ...         ...     ...         ...       ...       ...
# 497           dukat         0.0      RS  1540653678      41.0     42.44
# 498        acapulco        40.0      MX  1540648020      88.0     16.86
# 499          grants         1.0      US  1540652100      74.0     35.15
# 500           minab        40.0      IR  1540650600      74.0     27.15
# 501       gushikawa        75.0      JP  1540652160      52.0     26.35
# 502       spearfish        40.0      US  1540652100      47.0     44.49
# 503           adrar         0.0      DZ  1540652400      32.0     27.87
# 504            yaan        20.0      NG  1540653679      71.0      7.38
# 505         peniche        20.0      PT  1540652400      41.0     39.36
# 506        rosarito        40.0      CO  1540648800      72.0      4.91
# 507          pangoa        56.0      PE  1540653680      81.0    -12.12
# 508            dole        90.0      FR  1540652400      81.0     47.09
# 509           beira        40.0      ES  1540652400      62.0     43.20
# 510        ngunguru        76.0      NZ  1540653681     100.0    -35.62
# 511            mega        56.0      ET  1540653681      98.0      4.06
# 512         sorland        92.0      NO  1540653681     100.0     67.67
# 513         armeria        40.0      MX  1540651200      83.0     18.93
# 514       venezuela         0.0      CU  1540653682      91.0     21.74
# 515  nuevo progreso         1.0      US  1540652100      83.0     26.05
# 516         chitral         0.0      PK  1540653683      76.0     35.85
# 517      san miguel        40.0      AR  1540648800      59.0    -34.54
# 518        acuitzio        68.0      MX  1540653684      96.0     20.34
# 519       kyrylivka        20.0      UA  1540653684      68.0     47.32
# 520           conde         8.0      BR  1540653685      63.0    -11.81
# 521             leh        24.0      IN  1540653685      80.0     34.16
# 522         sanming         0.0      CN  1540653685      87.0     26.24
# 523         huanren        88.0      CN  1540653686      77.0     41.26
# 524      turukhansk        92.0      RU  1540653686      90.0     65.80
# 525        lakatoro        24.0      VU  1540653545     100.0    -16.11
# 526         ternate        75.0      PH  1540648800      69.0     14.29
#
#      Longitude  Max Temperature  Wind Speed
# 0       -97.45            71.27       18.75
# 1        54.10            80.60        4.70
# 2       -37.64            30.20       49.44
# 3       -68.31            48.20       20.80
# 4       118.78            38.24       10.36
# 5      -134.97            72.84       12.82
# 6       -24.50            80.22       13.27
# 7        20.71            62.36        2.42
# 8       112.04            42.80        8.95
# 9       -56.15            21.90       17.52
# 10       20.04            75.20       19.46
# 11      134.23            81.39       10.69
# 12       30.79            35.60       20.13
# 13       38.73            66.27       10.69
# 14     -127.42            44.60        5.82
# 15      168.86            42.51        3.20
# 16        6.91            37.40        6.67
# 17      -60.23            70.59       10.25
# 18      115.24            80.60        3.76
# 19       63.78            25.91       18.52
# 20     -173.23            25.37       14.05
# 21      -43.81            80.60        8.05
# 22      -95.96            62.60        5.32
# 23       26.89            72.57       14.72
# 24     -126.83            23.00        4.70
# 25      -66.85            84.09        9.46
# 26      -34.84            86.00       13.87
# 27       13.24            86.00       13.87
# 28      138.60            56.55        2.75
# 29      170.50            44.49        2.42
# ..         ...              ...         ...
# 497      22.31            62.54        3.65
# 498     -99.88            78.80        3.36
# 499    -107.85            37.40        3.36
# 500      57.07            84.20        4.70
# 501     127.87            71.60       16.11
# 502    -103.86            57.20        5.32
# 503      -0.29            82.40        5.82
# 504       8.57            88.14        4.76
# 505      -9.38            60.80       26.40
# 506     -75.23            69.80        2.24
# 507     -73.00            74.46        2.30
# 508       5.49            46.40       10.29
# 509      -8.36            51.80        9.17
# 510     174.50            62.13       18.97
# 511      38.32            62.13        2.98
# 512      12.69            42.02       22.10
# 513    -103.97            82.40        3.42
# 514     -78.80            83.82        3.98
# 515     -97.95            73.40        4.76
# 516      71.79            17.81        1.19
# 517     -58.72            66.20        4.43
# 518    -101.98            59.12        3.20
# 519      37.67            50.43       10.02
# 520     -37.61            87.15       14.50
# 521      77.58            -2.27        2.19
# 522     117.60            51.74        1.97
# 523     125.37            32.52        4.65
# 524      87.96            36.84       19.75
# 525     167.42            75.45        5.21
# 526     120.72            82.40        2.24
#
# [527 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Plot settings
def set_plot_prop(x_title,x_lim,y_title):
    plt.title(f"{x_title} vs {y_title}")
    plt.ylabel(y_title)
    plt.xlabel(x_title)
    plt.grid(True)
    plt.xlim(x_lim)

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Max Temperature",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Temperature (F)")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Temperature")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Humidity",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Humidity")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Humidity")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Cloudiness",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Cloudiness")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Cloudiness")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
list_of_cities.plot(kind="scatter",x="Latitude",y="Wind Speed",grid=True,color="blue")
set_plot_prop("Latitude",[-90,90],"Wind Speed")
plt.axvline(0, color='black',alpha=0.5)
plt.savefig("Latitude vs Wind Speed")
plt.show()
